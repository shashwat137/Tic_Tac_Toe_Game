# %%
import tic_tac_toe
# Out:
# Welcome to Tic Tac Toe
# There will be two players. Please select whether Player 1 is "X" or "O"
# Enter X or O for Player 1
# x
#
#
#
#
#
#
#
# Enter position for placing your attempt on board using numpad on your keyboard
# 8
#      |     |
#      |  X  |
# _____|_____|_____
#      |     |
#      |     |
# _____|_____|_____
#      |     |
#      |     |
#      |     |
#
#
#
#
#
#
#
# Enter position for placing your attempt on board using numpad on your keyboard
# 5
#      |     |
#      |  X  |
# _____|_____|_____
#      |     |
#      |  O  |
# _____|_____|_____
#      |     |
#      |     |
#      |     |
#
#
#
#
#
#
#
# Enter position for placing your attempt on board using numpad on your keyboard
# 1
#      |     |
#      |  X  |
# _____|_____|_____
#      |     |
#      |  O  |
# _____|_____|_____
#      |     |
#   X  |     |
#      |     |
#
#
#
#
#
#
#
# Enter position for placing your attempt on board using numpad on your keyboard
# 3
#      |     |
#      |  X  |
# ...
